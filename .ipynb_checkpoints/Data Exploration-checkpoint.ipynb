# %%
import geopandas as gpd

# Load the dataset
df = gpd.read_file('flood_control_projects.geojson')

# Basic statistics
print(f"Total projects: {len(df)}")
print(f"Regions covered: {df['Region'].nunique()}")
print(f"Date range: {df['CompletionYear'].min()} - {df['CompletionYear'].max()}")
# Out:
# Total projects: 9855
# Regions covered: 16
# Date range: 2022 - 2025

# %%
df.dtypes
# Out:
# InfraYear                               int32
# Region                                 object
# Province                               object
# Municipality                           object
# ImplementingOffice                     object
# ProjectID                              object
# ProjectDescription                     object
# ProjectComponentID                     object
# ProjectComponentDescription            object
# Program                                object
# TypeofWork                             object
# infra_type                             object
# Longitude                             float64
# Latitude                              float64
# ContractID                             object
# ABC                                   float64
# ContractCost                          float64
# CompletionDateOriginal                float64
# CompletionYear                          int32
# Contractor                             object
# ObjectId                                int32
# CreationDate                            int64
# Creator                                object
# EditDate                                int64
# Editor                                 object
# FundingYear                            object
# LegislativeDistrict                    object
# DistrictEngineeringOffice              object
# GlobalID                               object
# ABC_String                             object
# ContractCost_String                    object
# CompletionDateActual           datetime64[ms]
# StartDate                              object
# geometry                             geometry
# dtype: object

# %%
df["lon"] = df["geometry"].x
df["lat"] = df["geometry"].y
df
# Out:
#       InfraYear       Region           Province  \
# 0          2024  Region IV-B            PALAWAN
# 1          2024  Region IV-B            PALAWAN
# 2          2024  Region IV-B            PALAWAN
# 3          2023  Region IV-B            PALAWAN
# 4          2024  Region IV-B            PALAWAN
# ...         ...          ...                ...
# 9850       2022  Region XIII     AGUSAN DEL SUR
# 9851       2021  Region XIII     AGUSAN DEL SUR
# 9852       2023    Region XI       DAVAO DE ORO
# 9853       2022  Region XIII  SURIGAO DEL NORTE
# 9854       2023  Region XIII  SURIGAO DEL NORTE
#
#                                   Municipality  \
# 0     PUERTO PRINCESA CITY (CAPITAL) (PALAWAN)
# 1     PUERTO PRINCESA CITY (CAPITAL) (PALAWAN)
# 2     PUERTO PRINCESA CITY (CAPITAL) (PALAWAN)
# 3     PUERTO PRINCESA CITY (CAPITAL) (PALAWAN)
# 4     PUERTO PRINCESA CITY (CAPITAL) (PALAWAN)
# ...                                        ...
# 9850                   LORETO (AGUSAN DEL SUR)
# 9851                                      None
# 9852                   PANTUKAN (DAVAO DE ORO)
# 9853            DEL CARMEN (SURIGAO DEL NORTE)
# 9854                 PILAR (SURIGAO DEL NORTE)
#
#                                      ImplementingOffice    ProjectID  \
# 0               Palawan 3rd District Engineering Office  P00824759LZ
# 1               Palawan 3rd District Engineering Office  P00824758LZ
# 2               Palawan 3rd District Engineering Office  P00824750LZ
# 3               Palawan 3rd District Engineering Office  P00737551LZ
# 4                                           Region IV-B  P00823565LZ
# ...                                                 ...          ...
# 9850     Agusan del Sur 2nd District Engineering Office  P00620300MN
# 9851     Agusan del Sur 2nd District Engineering Office  P00522268MN
# 9852       Davao de Oro 1st District Engineering Office  P00721616MN
# 9853  Surigao del Norte 1st District Engineering Office  P00644676MN
# 9854  Surigao del Norte 1st District Engineering Office  P00745952MN
#
#                                      ProjectDescription ProjectComponentID  \
# 0     Construction of Babuyan River Flood Control St...    P00824759LZ-CW1
# 1     Construction of Flood Control Strucurue along ...    P00824758LZ-CW1
# 2     Construction of Babuyan River Flood Control St...    P00824750LZ-CW1
# 3     Construction of Flood Control Structure, Baran...    P00737551LZ-CW1
# 4     Construction of Tanabag River Waterway, (Upstr...    P00823565LZ-CW1
# ...                                                 ...                ...
# 9850  Construction of River Bank Protection along Ih...    P00620300MN-CW1
# 9851  Construction of River Bank Protection of Ihawa...    P00522268MN-CW1
# 9852  Construction of Revetment along Mabo Creek lea...    P00721616MN-CW1
# 9853  Construction/Rehabilitation of Caub Shore Prot...    P00644676MN-CW1
# 9854  Reconstruction/Rehabilitation of Seawall and R...    P00745952MN-CW1
#
#                             ProjectComponentDescription Program  ...  \
# 0     Construction of Flood Mitigation Structure - C...    None  ...
# 1     Construction of Flood Mitigation Structure - C...    None  ...
# 2     Construction of Flood Mitigation Structure - C...    None  ...
# 3     Construction of Drainage Structure - Construct...    None  ...
# 4     Construction of Flood Mitigation Structure - C...    None  ...
# ...                                                 ...     ...  ...
# 9850  Construction of Flood Mitigation Structure - C...    None  ...
# 9851  Construction of Flood Mitigation Structure - C...    None  ...
# 9852  Construction of Revetment - Construction of Re...    None  ...
# 9853  Construction of Flood Mitigation Structure - C...    None  ...
# 9854  Rehabilitation / Major Repair of Flood Control...    None  ...
#
#                                  LegislativeDistrict  \
# 0               PALAWAN (THIRD LEGISLATIVE DISTRICT)
# 1               PALAWAN (THIRD LEGISLATIVE DISTRICT)
# 2               PALAWAN (THIRD LEGISLATIVE DISTRICT)
# 3               PALAWAN (THIRD LEGISLATIVE DISTRICT)
# 4               PALAWAN (THIRD LEGISLATIVE DISTRICT)
# ...                                              ...
# 9850    AGUSAN DEL SUR (SECOND LEGISLATIVE DISTRICT)
# 9851    AGUSAN DEL SUR (SECOND LEGISLATIVE DISTRICT)
# 9852      DAVAO DE ORO (SECOND LEGISLATIVE DISTRICT)
# 9853  SURIGAO DEL NORTE (FIRST LEGISLATIVE DISTRICT)
# 9854  SURIGAO DEL NORTE (FIRST LEGISLATIVE DISTRICT)
#
#                               DistrictEngineeringOffice  \
# 0               Palawan 3rd District Engineering Office
# 1               Palawan 3rd District Engineering Office
# 2               Palawan 3rd District Engineering Office
# 3               Palawan 3rd District Engineering Office
# 4               Palawan 3rd District Engineering Office
# ...                                                 ...
# 9850     Agusan del Sur 2nd District Engineering Office
# 9851     Agusan del Sur 2nd District Engineering Office
# 9852       Davao de Oro 1st District Engineering Office
# 9853  Surigao del Norte 1st District Engineering Office
# 9854  Surigao del Norte 1st District Engineering Office
#
#                                   GlobalID    ABC_String ContractCost_String  \
# 0     79e8be69-90ab-488d-bf10-9204d41338ab      17963475         17961569.07
# 1     dea02c2f-d69d-4757-8d21-853e001736c5      17370000         17369992.99
# 2     7177ab8b-b330-40f5-bdda-44ce7823ddf8      18335000         16802607.63
# 3     fcf681df-bf3b-47a6-8807-01f94106bef9       4900000             4899590
# 4     a3d64d20-0d8d-4b61-abdd-38a3bd840c77  154399999.99        154395357.94
# ...                                    ...           ...                 ...
# 9850  0b8d3102-4221-497e-aebf-22108c35cc26      33765900            33765900
# 9851  cda42dcf-cc86-4936-9788-44a89a9ea713      49000000            49000000
# 9852  d4395e48-afb5-4520-a533-4b08e166fe3f      34300000         34299422.58
# 9853  d45c4d6e-fd39-4a9e-9af3-08275c148bb8      77200000         75671068.01
# 9854  d325ba80-3835-4111-b111-f883c1a1dd5e   93137880.05         92206234.28
#
#       CompletionDateActual   StartDate                   geometry         lon  \
# 0               2024-05-23  02/15/2024  POINT (118.89245 9.99653)  118.892450
# 1               2024-07-19  02/23/2024  POINT (118.89251 9.99761)  118.892510
# 2               2024-07-24  02/23/2024  POINT (118.89323 9.99671)  118.893230
# 3               2023-05-05  02/15/2023  POINT (118.8997 10.00266)  118.899702
# 4               2024-09-05  03/09/2024  POINT (118.99018 9.99904)  118.990177
# ...                    ...         ...                        ...         ...
# 9850            2023-05-19  07/11/2022  POINT (125.87772 8.12369)  125.877717
# 9851            2022-07-27  08/02/2021  POINT (125.88172 8.11825)  125.881720
# 9852            2023-12-24  03/10/2023  POINT (125.89091 7.13826)  125.890907
# 9853            2024-04-05  11/25/2022  POINT (125.89527 9.89528)  125.895270
# 9854            2024-05-19  11/28/2023  POINT (125.90556 9.64528)  125.905556
#
#             lat
# 0      9.996530
# 1      9.997610
# 2      9.996710
# 3     10.002658
# 4      9.999043
# ...         ...
# 9850   8.123692
# 9851   8.118250
# 9852   7.138258
# 9853   9.895280
# 9854   9.645278
#
# [9855 rows x 36 columns]
